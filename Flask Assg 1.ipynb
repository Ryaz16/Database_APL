# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries.
#
# #higher flexibility.
# #higher compatibility with latest technologies.
# #high scalability for simple web applications.
# #technical experimentation.
# #customization.
# #slightly higher framework performance.
# #easier to use for simple cases.
# #smaller size of the code base.

# %% [markdown]
# higher flexibility.
# higher compatibility with latest technologies.
# high scalability for simple web applications.
# technical experimentation.
# customization.
# slightly higher framework performance.
# easier to use for simple cases.
# smaller size of the code base.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello World!!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
#  App routing is used to map the specific URL with the associated function that is intended to perform some task.
#
#  Web frameworks use the routing technique to help users remember application URLs. List the different methods to bind the URLs to their associated functions.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def hello_world():
    return "<h1>Welcome to Diamond Corporation</h1>"

@app.route("/")
def details():
    return """Company Name: Diamond Corporation 
    Location: India
    Contact Details: 9989898989"""

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
#  --> url_for() method, is used to prepare a URL, for a function dynamically
